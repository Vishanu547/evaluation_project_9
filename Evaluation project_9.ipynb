# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data = data.drop(columns=['customerID'])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc = LabelEncoder()

# %%
data1 = lab_enc.fit_transform(data['gender'])
data2 = lab_enc.fit_transform(data['Partner'])
data3 = lab_enc.fit_transform(data['Dependents'])
data4 = lab_enc.fit_transform(data['PhoneService'])
data5 = lab_enc.fit_transform(data['MultipleLines'])
data6 = lab_enc.fit_transform(data['InternetService'])
data7 = lab_enc.fit_transform(data['OnlineSecurity'])
data8 = lab_enc.fit_transform(data['OnlineBackup'])
data9 = lab_enc.fit_transform(data['DeviceProtection'])
data10 = lab_enc.fit_transform(data['TechSupport'])
data11 = lab_enc.fit_transform(data['StreamingTV'])
data12 = lab_enc.fit_transform(data['StreamingMovies'])
data13 = lab_enc.fit_transform(data['Contract'])
data14 = lab_enc.fit_transform(data['PaperlessBilling'])
data15 = lab_enc.fit_transform(data['PaymentMethod'])
data16 = lab_enc.fit_transform(data['TotalCharges'])
data17 = lab_enc.fit_transform(data['Churn'])

# %%
data['gender'] = data1
data['Partner'] = data2
data['Dependents'] = data3
data['PhoneService'] = data4
data['MultipleLines'] = data5
data['InternetService'] = data6
data['OnlineSecurity'] = data7
data['OnlineBackup'] = data8
data['DeviceProtection'] = data9
data['TechSupport'] = data10
data['StreamingTV'] = data11
data['StreamingMovies'] = data12
data['Contract'] = data13
data['PaperlessBilling'] = data14
data['PaymentMethod'] = data15
data['TotalCharges'] = data16
data['Churn'] = data17

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int32
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int32
#  6   MultipleLines     7043 non-null   int32
#  7   InternetService   7043 non-null   int32
#  8   OnlineSecurity    7043 non-null   int32
#  9   OnlineBackup      7043 non-null   int32
#  10  DeviceProtection  7043 non-null   int32
#  11  TechSupport       7043 non-null   int32
#  12  StreamingTV       7043 non-null   int32
#  13  StreamingMovies   7043 non-null   int32
#  14  Contract          7043 non-null   int32
#  15  PaperlessBilling  7043 non-null   int32
# ...

# %%
data.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize = [20,15],facecolor='g')
plotno = 1


for column in data:
    if plotno<=20:
        ax = plt.subplot(4,5,plotno)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=12)
        
    plotno+=1
    
    
plt.show()

# %%
x = data.drop(columns=['Churn'])
y = data['Churn']

# %%
plt.figure(figsize = (25,35))
plno = 1

for column in x:
    if plno<=20:
        plt.subplot(4,5,plno)
        sns.stripplot(y,x[column])
        
        
    plno+=1    

plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scalar = StandardScaler()
x_scaled = scalar.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 19

# %%
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i)for i in range(x_scaled.shape[1])]
vif['features'] = x.columns
vif
# Out:
#          vif          features
# 0   1.001684            gender
# 1   1.149738     SeniorCitizen
# 2   1.460866           Partner
# 3   1.382201        Dependents
# 4   2.754534            tenure
# 5   1.622290      PhoneService
# 6   1.392832     MultipleLines
# 7   1.826667   InternetService
# 8   1.247891    OnlineSecurity
# 9   1.186358      OnlineBackup
# 10  1.280276  DeviceProtection
# 11  1.303577       TechSupport
# 12  1.443671       StreamingTV
# 13  1.442485   StreamingMovies
# 14  2.474411          Contract
# 15  1.203895  PaperlessBilling
# 16  1.181060     PaymentMethod
# 17  2.830593    MonthlyCharges
# 18  1.108732      TotalCharges

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.25,random_state = 19)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8057921635434412

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7637705848949461

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7314026121521863

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = dt.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7314026121521863

# %%
### logistic regression is the best model for this dataset beacuse it's give the best accuracy score

# %%
data.tail(1)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 7042              0                1               2             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 7042                 2            2            2                2         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 7042                 1              0          105.65          5407      0

# %%
print('churn :',log_reg.predict(scalar.transform([[1,0,0,0,66,1,0,1,2,0,2,2,2,2,2,1,0,105.65,5407]])))
# Out:
# churn : [0]

# %%
## grid search cv

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100] }

# %%
gsc = GridSearchCV(estimator=log_reg,param_grid=param_grid)

# %%
gsc.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100]})

# %%
gsc.best_params_
# Out:
# {'C': 0.1}

# %%
log_reg = LogisticRegression(C= 0.1)

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression(C=0.1)

# %%
y_pred = log_reg.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.807495741056218

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1296
#            1       0.67      0.53      0.59       465
#
#     accuracy                           0.81      1761
#    macro avg       0.76      0.72      0.73      1761
# weighted avg       0.80      0.81      0.80      1761

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1174  122]
#  [ 217  248]]

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
fpr,tpr,Thresholds = roc_curve(y_test,y_pred)

# %%
print('Thresholds =',Thresholds)
print('fpr =',fpr)
print('tpr =',tpr)
# Out:
# Thresholds = [2 1 0]
# fpr = [0.        0.0941358 1.       ]
# tpr = [0.         0.53333333 1.        ]

# %%
plt.plot(fpr,tpr,color='orange',label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue',linestyle = '--')
plt.xlabel('FalsePositiveRate')
plt.ylabel('TruepositiveRate')
plt.title('receiver operating characteristic(roc)curve')
plt.legend()
plt.show()
